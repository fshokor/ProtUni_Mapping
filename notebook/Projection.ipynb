# %% [markdown]
# # Load Packages

# %%
import numpy as np
import pandas as pd
import os
import glob
import pickle
import tensorflow as tf
# For plotting
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import normalize
from matplotlib.lines import Line2D
import matplotlib.colors as mcolors

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Load DataFrame

# %%
# load datframe generated in encoding notebook (with ccords)
df = pd.read_csv('/content/gdrive/MyDrive/Projet_long/dataframe/df2.csv').iloc[: , 1:]

# %% [markdown]
# ## Plot

# %%
color_dict_types1 = { 'Real':'green', 'Artificial':'blue', 'Expected':'red'}
plt.figure(figsize=(20, 15))
plt.scatter(fold_df.x_coords, fold_df.y_coords, marker='o',c=[color_dict_types1[i] for i in fold_df['Types']])
markers = [plt.Line2D([0,0],[0,0],color=color, marker='o', linestyle='') for color in color_dict_types1.values()]
plt.legend(markers, color_dict_types1.keys(), numpoints=1, prop={'size': 15})
plt.savefig('/content/gdrive/MyDrive/Projet_long/art_real_tsne_exp.png')
plt.show()
